# %%
import pandas as pd
import numpy as np
import warnings as wr
import matplotlib as mpl
import seaborn as sns

# %%
#Variable definitions

# DATOP - Date of flight
# FLTID - Flight number
# DEPSTN - Departure point
# ARRSTN - Arrival point
# STD - Scheduled Time departure
# STA - Scheduled Time arrival
# STATUS - Flight status
# ETD - Expected Time departure
# ETA - Expected Time arrival
# ATD - Actual Time of Departure
# ATA - Actual Time of arrival
# DELAY1 - Delay code 1
# DUR1 - delay time 1
# DELAY2 - Delay code 2
# DUR2 - delay time 2
# DELAY3 - Delay code 3
# DUR3 - delay time 3
# DELAY4 - Delay code 4
# DUR4 - delay time 4
# AC - Aircraft Code

# %%
import airportsdata
airports = airportsdata.load()  # key is the ICAO identifier (the default)
print(airports['KJFK'])
# Out:
# {'icao': 'KJFK', 'iata': 'JFK', 'name': 'John F Kennedy International Airport', 'city': 'New York', 'subd': 'New York', 'country': 'US', 'elevation': 13.0, 'lat': 40.6399277777778, 'lon': -73.7786925, 'tz': 'America/New_York', 'lid': 'JFK'}

# %%
df_train= pd.read_csv('data/Train.csv')
df_train.nunique()
# Out:
# ID        107833
# DATOP       1011
# FLTID       1861
# DEPSTN       132
# ARRSTN       128
# STD        81697
# STA        85136
# STATUS         5
# AC            68
# target       968
# dtype: int64

# %%
df_train
# Out:
#                      ID       DATOP      FLTID DEPSTN ARRSTN
# 0            train_id_0  2016-01-03   TU 0712     CMN    TUN  \
# 1            train_id_1  2016-01-13   TU 0757     MXP    TUN
# 2            train_id_2  2016-01-16   TU 0214     TUN    IST
# 3            train_id_3  2016-01-17   TU 0480     DJE    NTE
# 4            train_id_4  2016-01-17   TU 0338     TUN    ALG
# ...                 ...         ...        ...    ...    ...
# 107828  train_id_107828  2018-07-05  WKL 0000     TUN    TUN
# 107829  train_id_107829  2018-01-13   UG 0003     DJE    TUN
# 107830  train_id_107830  2018-11-07  SGT 0000     TUN    TUN
# 107831  train_id_107831  2018-01-23   UG 0010     TUN    DJE
# 107832  train_id_107832  2018-11-13   UG 0002     TUN    DJE
#
#                         STD                  STA STATUS         AC  target
# 0       2016-01-03 10:30:00  2016-01-03 12.55.00    ATA  TU 32AIMN   260.0
# 1       2016-01-13 15:05:00  2016-01-13 16.55.00    ATA  TU 31BIMO    20.0
# ...

# %%
df_test= pd.read_csv('data/test.csv')
df_test
# Out:
#                 ID       DATOP      FLTID DEPSTN ARRSTN                  STD
# 0        test_id_0  2016-05-04   TU 0700     DJE    TUN  2016-05-04 06:40:00  \
# 1        test_id_1  2016-05-05   TU 0395     TUN    BKO  2016-05-05 15:20:00
# 2        test_id_2  2016-05-06   TU 0745     FRA    TUN  2016-05-06 10:00:00
# 3        test_id_3  2016-05-11   TU 0848     BEY    TUN  2016-05-11 09:40:00
# 4        test_id_4  2016-05-11   TU 0635     ORY    MIR  2016-05-11 09:50:00
# ...            ...         ...        ...    ...    ...                  ...
# 9328  test_id_9328  2018-09-12   TU 0998     TUN    NCE  2018-09-12 14:15:00
# 9329  test_id_9329  2018-09-27  WKL 0000     TUN    TUN  2018-09-27 22:00:00
# 9330  test_id_9330  2018-09-03   UG 1601     SJJ    TUN  2018-09-03 09:20:00
# 9331  test_id_9331  2018-09-15   UG 0008     TUN    DJE  2018-09-15 14:30:00
# 9332  test_id_9332  2018-09-19   UG 0009     DJE    TUN  2018-09-19 16:15:00
#
#                       STA STATUS         AC
# ...

# %%
df_ss = pd.read_csv('data/samplesubmission.csv')
df_ss
# Out:
#                 ID  target
# 0        test_id_0    2470
# 1        test_id_1    2944
# 2        test_id_2    2585
# 3        test_id_3    3264
# 4        test_id_4    1369
# ...            ...     ...
# 9328  test_id_9328    2155
# 9329  test_id_9329    3444
# 9330  test_id_9330     921
# 9331  test_id_9331     130
# 9332  test_id_9332    2857
#
# [9333 rows x 2 columns]

# %%
df_air= pd.DataFrame(airports)
df_air.head(20)
# Transpose the DataFrame
df_air_trans = df_air.transpose()
# If you want to reset the index of the transposed DataFrame
df_air_trans.reset_index(drop=True, inplace=True)
df_air_trans
# Out:
#        icao iata                         name          city       subd
# 0      00AA              Aero B Ranch Airport         Leoti     Kansas  \
# 1      00AK                      Lowell Field  Anchor Point     Alaska
# 2      00AL                      Epps Airpark       Harvest    Alabama
# 3      00AN              Katmai Lodge Airport   King Salmon     Alaska
# 4      00AR                    Arland Airport    Bennington     Kansas
# ...     ...  ...                          ...           ...        ...
# 28171  ZYXC  XEN           Xingcheng Air Base                 Liaoning
# 28172  ZYYJ  YNJ  Yanji Chaoyangchuan Airport         Yanji      Jilin
# 28173  ZYYY           Shenyang Dongta Airport      Shenyang   Liaoning
# 28174  _AYM  AYM     Yas Island Seaplane Base    Yas Island  Abu Dhabi
# 28175  _OUK  OUK        Out Skerries Airstrip      Shetland   Scotland
#
#       country elevation        lat         lon                 tz   lid
# ...

# %% [markdown]
# ## Splitting data for testing

# %% [markdown]
# ## Trainining the model
